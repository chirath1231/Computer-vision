# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (2.2.6)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
image = cv2.imread("image.jpg")
if image is not None:
    print("Image read successfully!")
else:
    print("Failed to read the image.")
# Out:
# Image read successfully!

# %%
#display the image
img = cv2.resize(image, (600, 400))

cv2.imshow("Image", img)



cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#writing the image
img_new = img +30 
cv2.imwrite("output.jpg", img_new)
# Out:
# True
