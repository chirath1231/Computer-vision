# %%
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\user\pycharmprojects\jupyterproject1\.venv\lib\site-packages (2.2.6)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("img.png")

# %%
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_hsv = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
plt.imshow(image_rgb)

# %%
lower_white = np.array([0,0,190])
upper_white = np.array([30,80,255])
mask = cv2.inRange(image_hsv,lower_white,upper_white)
plt.imshow(mask)

# %%
black_hsv = np.uint8([[[120,255,0]]]) # black pixel
black_bgr = cv2.cvtColor(black_hsv,cv2.COLOR_HSV2BGR)[0][0]

# %%
image_result = image.copy()

# %%
image_result[mask>0] = black_bgr
image_result_rgb = cv2.cvtColor(image_result,cv2.COLOR_BGR2RGB)

# %%
fig, axs = plt.subplots(1,3, figsize=(12,6))

axs[0].imshow(image_rgb)
axs[0].set_title("Original Image")
axs[0].axis('off')

axs[1].imshow(mask)
axs[1].set_title("Binary Mask")
axs[1].axis('off')


axs[2].imshow(image_result_rgb)
axs[2].set_title("Output Image")
axs[2].axis('off')

plt.tight_layout()
plt.show()
